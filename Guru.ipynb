# %%
from pathlib import Path
import pandas as pd
file_path = Path("Resources/dummyData.csv")
tweetsData = pd.read_csv(file_path, index_col="Datetime" )
# tweetData = tweetsData.set_index('time')
tweetsData.tail()
# Out:
#                                                                        tweet  \
# Datetime
# 2022-05-29 05:19:59+00:00  @cryptoworld202 @omniaverse DApp features:\n\n...
# 2022-05-29 05:19:59+00:00  RT @dreamcity1991: #Shiba is the future of #ET...
# 2022-05-29 05:19:59+00:00  RT @LadyofCrypto1: ☝️ even if #Bitcoin turns a...
# 2022-05-29 05:19:59+00:00  Meet the Steel Company that Wants to Become an...
# 2022-05-29 05:19:59+00:00  RT @CryptoReloader: You lost your money throug...
#
#                            probability sentiment
# Datetime
# 2022-05-29 05:19:59+00:00     0.973206  POSITIVE
# 2022-05-29 05:19:59+00:00     0.997723  POSITIVE
# 2022-05-29 05:19:59+00:00     0.939273  NEGATIVE
# 2022-05-29 05:19:59+00:00     0.997355  NEGATIVE
# 2022-05-29 05:19:59+00:00     0.998999  NEGATIVE

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("BTC-USD", start="2022-05-29", end="2022-05-30", interval="1m")

data['actual_returns'] = data['Close'].pct_change()
data
# merged_pdf = pd.concat([tweetsData, data[['actual_returns']]], join="outer", axis=0)
# merged_pdf.dropna()
# merged_pdf
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2022-05-28 14:00:00+00:00  29056.457031  29056.457031  29056.457031
# 2022-05-28 14:01:00+00:00  29056.253906  29056.253906  29056.253906
# 2022-05-28 14:02:00+00:00  29066.771484  29066.771484  29066.771484
# 2022-05-28 14:03:00+00:00  29064.525391  29064.525391  29064.525391
# 2022-05-28 14:04:00+00:00  29061.273438  29061.273438  29061.273438
# ...                                 ...           ...           ...
# 2022-05-29 13:55:00+00:00  29329.970703  29329.970703  29329.970703
# 2022-05-29 13:56:00+00:00  29323.894531  29323.894531  29323.894531
# 2022-05-29 13:57:00+00:00  29319.662109  29319.662109  29319.662109
# 2022-05-29 13:58:00+00:00  29313.562500  29313.562500  29313.562500
# 2022-05-29 13:59:00+00:00  29314.597656  29314.597656  29314.597656
#
#                                   Close     Adj Close    Volume  \
# ...

# %%
# tickers = ['MSFT']

# # Create the Alpaca API object
# alpaca = tradeapi.REST(
#     "2c4d0dab866ee474c065318f278c1a01",
#     "c3b3f2fda0f0ac0d8e7a271c8456a32a71f97ffc",
#     api_version="v2",
#     # base_url="https://paper-api.alpaca.markets"
# )

# # Get current price data for MSFT and AAPL
# df_portfolio = alpaca.get_bars(tickers, tradeapi.TimeFrame.Day, "2022-05-31", "2022-05-02").df

# # Display sample data
# df_portfolio.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/gl/8c7qtydj695ck0zkw13mvcw00000gp/T/ipykernel_42335/386471411.py in <module>
#      10
#      11 # Get current price data for MSFT and AAPL
# ---> 12 df_portfolio = alpaca.get_bars(tickers, tradeapi.TimeFrame.Day, "2022-05-31", "2022-05-02").df
#      13
#      14 # Display sample data
#
# ~/miniconda3/envs/algotrading/lib/python3.7/site-packages/alpaca_trade_api/rest.py in get_bars(self, symbol, timeframe, start, end, adjustment, limit)
#     675                                        adjustment,
#     676                                        limit,
# --> 677                                        raw=True))
#     678         return BarsV2(bars)
#     679
#
# ...
